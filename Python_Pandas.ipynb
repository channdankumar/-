# %% [markdown]
# <a href="https://colab.research.google.com/github/channdankumar/-/blob/main/Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name": ['Chandan', 'Dev', 'Rahul', 'Harsh'],
    "marks": [12, 14, 15, 17],
    "city": ['Muzaffarpur', 'Bihar', 'Patna', 'Darbhanga']
}

# %%
df = pd.DataFrame(dict1)

# %%
df.head(2)
# Out:
#        name        toy       born
# 0  Superman        NaN        NaT
# 1    Batman  Batmobile 1956-06-26

# %%
df.to_csv('Frienda.csv')

# %%
df.head(3)
# Out:
#         name            toy       born
# 0   Superman            NaN        NaT
# 1     Batman      Batmobile 1956-06-26
# 2  Spiderman  Spiderman toy        NaT

# %%
df.tail(2)
# Out:
#     name  marks       city
# 2  Rahul     15      Patna
# 3  Harsh     17  Darbhanga

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   14.500000
# std     2.081666
# min    12.000000
# 25%    13.500000
# 50%    14.500000
# 75%    15.500000
# max    17.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['name', 'marks', 'city'], dtype='object')

# %%
df.T
# Out:
#                  0      1      2          3
# name       Chandan    Dev  Rahul      Harsh
# marks           12     14     15         17
# city   Muzaffarpur  Bihar  Patna  Darbhanga

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#       name  marks         city
# 0  Chandan     12  Muzaffarpur
# 1      Dev     14        Bihar
# 2    Rahul     15        Patna
# 3    Harsh     17    Darbhanga

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#       name  marks         city
# 3    Harsh     17    Darbhanga
# 2    Rahul     15        Patna
# 1      Dev     14        Bihar
# 0  Chandan     12  Muzaffarpur

# %%
df
# Out:
#       name  marks         city
# 0  Chandan     12  Muzaffarpur
# 1      Dev     14        Bihar
# 2    Rahul     15        Patna
# 3    Harsh     17    Darbhanga

# %%
df.loc[1,'name']= 'Dev Singh'

# %%
df
# Out:
#         name            toy       born
# 0   Superman            NaN        NaT
# 1  Dev Singh      Batmobile 1956-06-26
# 2  Spiderman  Spiderman toy        NaT

# %%
df.iloc[[0,2],[1,2]]
# Out:
#              toy born
# 0            NaN  NaT
# 2  Spiderman toy  NaT

# %%
df.iloc[0,2]
# Out:
# 'Muzaffarpur'

# %%
df.drop([0])
# Out:
#     name  marks       city
# 1    Dev     14      Bihar
# 2  Rahul     15      Patna
# 3  Harsh     17  Darbhanga

# %%
df.drop(['name'], axis=1)
# Out:
#    marks         city
# 0     12  Muzaffarpur
# 1     14        Bihar
# 2     15        Patna
# 3     17    Darbhanga

# %%
df.reset_index()
# Out:
#    index          name  marks         city
# 0      0  ChandanYadav     12  Muzaffarpur
# 1      1           Dev     14        Bihar
# 2      2         Rahul     15        Patna
# 3      3         Harsh     17    Darbhanga

# %%
df.reset_index(drop=True)
# Out:
#            name  marks         city
# 0  ChandanYadav     12  Muzaffarpur
# 1           Dev     14        Bihar
# 2         Rahul     15        Patna
# 3         Harsh     17    Darbhanga

# %%
df.loc[:,['name']]
# Out:
#            name
# 0  ChandanYadav
# 1           Dev
# 2         Rahul
# 3         Harsh

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
df.head()
# Out:
#         name            toy       born
# 0   Superman            NaN        NaT
# 1     Batman      Batmobile 1956-06-26
# 2  Spiderman  Spiderman toy        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1956-06-26

# %%
df.dropna( axis='columns')
# Out:
#         name
# 0   Superman
# 1     Batman
# 2  Spiderman

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
# <ipython-input-50-ea8415b8a3ee>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#             name        toy                 born
# count          3          2                    1
# unique         3          2                    1
# top     Superman  Batmobile  1956-06-26 00:00:00
# freq           1          1                    1
# first        NaN        NaN  1956-06-26 00:00:00
# last         NaN        NaN  1956-06-26 00:00:00

# %%
df['toy'].value_counts(dropna=True)
# Out:
# Batmobile        1
# Spiderman toy    1
# Name: toy, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df.mean()
# Out:
# <ipython-input-55-c61f0c8f89b5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# <ipython-input-55-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Series([], dtype: float64)

# %%
df.corr()
# Out:
# <ipython-input-56-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.count()
# Out:
# name    3
# toy     2
# born    1
# dtype: int64

# %%
df.max()
# Out:
# <ipython-input-58-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# name               Superman
# born    1956-06-26 00:00:00
# dtype: object

# %%
df.min()
# Out:
# <ipython-input-59-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# name                 Batman
# born    1956-06-26 00:00:00
# dtype: object

# %%
df.median()
# Out:
# <ipython-input-60-6d467abf240d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()
# <ipython-input-60-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Series([], dtype: float64)

# %%
df.std()
# Out:
# <ipython-input-63-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# born   NaT
# dtype: timedelta64[ns]

# %%
# Create a dataframe which contains only integere with 3 row and 2 columns
# run following dataframe method on them
 df.describe()
 df.max()
 df.min()
 df.count()
 df.min()
 df.median()
 df.std()
